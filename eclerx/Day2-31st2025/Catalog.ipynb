# %%
# %sql
Create catalog if not exists "dev";

# %%
# %sql
create Schema if not exists dev.demo;

# %%
# %sql
create table if not exists dev.demo.sample(id int, name string)

# %%
# %sql
insert into dev.demo.sample values(1, 'Rahul')

# %% [markdown]
# CTAS(create table as select)

# %%
# %sql
create or replace table dev.demo.sales_transactions
As select * from samples.bakehouse.sales_transactions

# %%
# %sql
select * from dev.demo.sales_transactions;

# %%
from pyspark.sql.functions import *

# %%
input_path = "/Volumes/dev/default/raw"

# %%
def add_ingestion_timestamp(df):
    return df.withColumn("ingestion_timestap",current_timestamp())

# %%
# %sql
use catalog dev;
create schema if not exists 1_bronze;
create schema if not exists 1_silver;
create schema if not exists 1_gold;

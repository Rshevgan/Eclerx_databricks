# %% [markdown]
# ![](path)

# %%
Ways to create table

1. Spark
2. spark sql
  -- CTAS
    1. select * from file_format.`path`  --->(single line json, parquet, delta, iceberg)
    2. select * from read_files("path", file_format => 'csv') -->(csv,multiline json, single line json, parquet, delta, iceberg, xml)  new version ahai so haich use kar
3. UI(limited)

# %%
# %sql
use catalog dev;
use schema demo;

# %%
# %sql
select * from json.`/Volumes/dev/demo/raw/input/retail_orders.json`

# %%
# %sql
create table dev.demo.financial_dataset as
select * from read_files("/Volumes/dev/demo/raw/input/financial_dataset.csv",format => "csv")

# %%
# %sql
create table dev.demo.T_parquet as
select * from read_files("/Volumes/dev/demo/raw/input/part-00000-4ece8039-e05f-4114-8262-9d82c9ee1e62-c000.snappy.parquet",format => "parquet")

# %%
# %sql
create table dev.demo.retail_orders as
select * from read_files("/Volumes/dev/demo/raw/input/retail_orders.json",format=> "json")

# %% [markdown]
# Pyspark

# %%
df = spark.read.csv("/Volumes/dev/demo/raw/input/financial_dataset.csv",header = 'true',inferSchema='true')
df.display()

# %%
df.write.mode("overwrite").saveAsTable("dev.demo.financial_dataset_pyspark")

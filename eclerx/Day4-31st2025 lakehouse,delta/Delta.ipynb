# %%
# %sql
use catalog dev;
use schema demo;

# %%
# %sql
create table emp_delta(id int, name string);
create table emp_iceberg(id int, name string) using iceberg

# %%
# %sql
insert into dev.demo.emp_delta values(1,'rahul');
insert into dev.demo.emp_iceberg values(1, 'rahul');

# %%
# %sql
desc extended dev.demo.emp_delta;
desc extended dev.demo.emp_iceberg;

desc detail dev.demo.emp_delta;

desc history dev.demo.emp_delta;
